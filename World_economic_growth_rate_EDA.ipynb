# %% [markdown]
# ### 세계 경제 성장률 EDA
# ---
#
#
# #### 데이터 활용 내용
#
# - 연도별 세계 경제 성장률 데이터
# - 한국만 사용할 예정
# - 연도별 데이터를 일별로 결합시켜 사용.
# - 국내총생산, 1인당 GDP, GDP성장률, 소비자물가, 수출, 수입 가격 간 관계 비교
# - ‘소비자물가지수’ 를 변수로 사용하기 위한 추가 자료 조사 필요
#
#
#
# #### 데이터 셋 분석 기간
# - 2013.01.01 ~ 2018.12.31

# %%
import pandas as pd
import numpy as np
#from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# data load
growth_rate = pd.read_csv('./data/05. 세계경제성장률.csv', encoding='cp949')
target_data = pd.read_csv("./data/01. 축산물 실시간 경매시황중계정보.csv", encoding="cp949")

# target data set-up
target_data = target_data[target_data["도매시장명"] == "전국"]
target_data = target_data[target_data["경매 구분 명"] == "경매용+지육상장"]
target_data = target_data[["경매시간", "경매기준시분초", "한우 평균경매 금액"]]
target_data = target_data[target_data["한우 평균경매 금액"] != 0]
sort_target_data = target_data.sort_values(by=["경매시간", "경매기준시분초"]) # Sort descending by Time
sort_target_data[["경매시간", "경매기준시분초"]] = sort_target_data[["경매시간", "경매기준시분초"]].astype("str")
target_data = sort_target_data
print("===Target DataSet===")
target_data.head()
# Out:
# ===Target DataSet===
#            경매시간 경매기준시분초  한우 평균경매 금액
# 34896  20130102  221544       13203
# 34867  20130103  221545       13743
# 34811  20130104  221545       13945
# 34666  20130107  221547       13470
# 34634  20130108  221548       14040

# %%
print("===World growth rate DataSet===")
growth_rate.head()
# Out:
# ===World growth rate DataSet===
#     국가별                         1990                1990.1       1990.2  \
# 0   국가별  국내총생산(GDP)(당해년 가격) (10억US$)  1인당 GDP(당해년 가격) (달러)  GDP 성장률 (%)
# 1    세계                            -                     -            -
# 2   아시아                          NaN                   NaN          NaN
# 3    한국                            -                     -            -
# 4  이스라엘                         58.9                 12645          7.3
#
#         1990.3       1990.4    1990.5   1990.6              1990.7  \
# 0  수출 (100만달러)  수입 (100만달러)  총인구 (천명)  실업률 (%)  소비자물가지수 (2010=100)
# 1      3446279      3562626   5327231        -                   -
# 2          NaN          NaN       NaN      NaN                 NaN
# 3        65016        69844     42869      2.4                40.6
# 4        11576        16791      4448     12.2                32.5
#
#             1990.8  ...                         2019                2019.1  \
# 0  조강생산량 (1000M/T)  ...  국내총생산(GDP)(당해년 가격) (10억US$)  1인당 GDP(당해년 가격) (달러)
# 1                -  ...                            -                     -
# 2              NaN  ...                          NaN                   NaN
# 3                -  ...                            -                     -
# 4                -  ...                            -                     -
#
#         2019.2       2019.3       2019.4    2019.5   2019.6  \
# 0  GDP 성장률 (%)  수출 (100만달러)  수입 (100만달러)  총인구 (천명)  실업률 (%)
# 1            -            -            -   7713468        -
# 2          NaN          NaN          NaN       NaN      NaN
# 3            -            -            -     51709        -
# 4            -            -            -      8519        -
#
#                2019.7           2019.8       2019.9
# 0  소비자물가지수 (2010=100)  조강생산량 (1000M/T)  인터넷 이용률 (%)
# 1                   -                -            -
# 2                 NaN              NaN          NaN
# 3                   -                -            -
# 4                   -                -            -
#
# [5 rows x 301 columns]

# %% [markdown]
# ### DataSet Preprocessing
# ---
#
# 행렬 변환 후 연도별로 데이터 나열

# %%
korea_data = growth_rate[growth_rate["국가별"]=="한국"]
korea_data = korea_data.T.iloc[1:]
korea_data.head()
# Out:
#             3
# 1990        -
# 1990.1      -
# 1990.2      -
# 1990.3  65016
# 1990.4  69844

# %%
years = [y for y in range(1990, 2020)]
data = []

for i in range(0, len(korea_data), 10):
    data += [list(korea_data[3].iloc[i:i+10])]
for i in range(len(years)):
    data[i] = [years[i]] + data[i] 
    

korea_growth_rate = pd.DataFrame(data, columns=["연도"] + list(growth_rate.iloc[0][1:11]))
korea_growth_rate = korea_growth_rate[korea_growth_rate["연도"] >= 2013].iloc[:-1]
korea_growth_rate.head()
# Out:
#       연도 국내총생산(GDP)(당해년 가격) (10억US$) 1인당 GDP(당해년 가격) (달러) GDP 성장률 (%)  \
# 23  2013                      1370.6                27178         3.2
# 24  2014                      1484.0                29242         3.2
# 25  2015                      1465.3                28724         2.8
# 26  2016                      1500.0                29287         2.9
# 27  2017                      1623.3                31605         3.2
#
#    수출 (100만달러) 수입 (100만달러) 총인구 (천명) 실업률 (%) 소비자물가지수 (2010=100)  \
# 23      559632      515586    50429     3.1               98.0
# 24      572665      525515    50747     3.5               99.3
# 25      526757      436499    51015     3.6              100.0
# 26      495426      406193    51218     3.7              101.0
# 27      573694      478478    51362     3.7              102.9
#
#    조강생산량 (1000M/T) 인터넷 이용률 (%)
# 23           66061        84.8
# 24           71543        87.6
# 25           69670        89.9
# 26           68576        92.8
# 27           71030        95.1

# %% [markdown]
# ### Korea Economic Growth Rate EDA
# ---

# %%
print(f"Korea Economic Growth Rate Data Shape : {korea_growth_rate.shape}")
korea_growth_rate
# Out:
# Korea Economic Growth Rate Data Shape : (6, 11)
#       연도 국내총생산(GDP)(당해년 가격) (10억US$) 1인당 GDP(당해년 가격) (달러) GDP 성장률 (%)  \
# 23  2013                      1370.6                27178         3.2
# 24  2014                      1484.0                29242         3.2
# 25  2015                      1465.3                28724         2.8
# 26  2016                      1500.0                29287         2.9
# 27  2017                      1623.3                31605         3.2
# 28  2018                      1720.9                33346         2.7
#
#    수출 (100만달러) 수입 (100만달러) 총인구 (천명) 실업률 (%) 소비자물가지수 (2010=100)  \
# 23      559632      515586    50429     3.1               98.0
# 24      572665      525515    50747     3.5               99.3
# 25      526757      436499    51015     3.6              100.0
# 26      495426      406193    51218     3.7              101.0
# 27      573694      478478    51362     3.7              102.9
# 28      604860      535202    51607     3.8              104.5
#
#    조강생산량 (1000M/T) 인터넷 이용률 (%)
# 23           66061        84.8
# 24           71543        87.6
# 25           69670        89.9
# 26           68576        92.8
# 27           71030        95.1
# 28               -        95.9

# %% [markdown]
# ##### 2019 년 조강생산량 평균값으로 대치

# %%
korea_growth_rate["조강생산량 (1000M/T)"].iloc[-1] = sum([int(v) for v in korea_growth_rate["조강생산량 (1000M/T)"][:-1]]) / 5
korea_growth_rate
# Out:
#       연도 국내총생산(GDP)(당해년 가격) (10억US$) 1인당 GDP(당해년 가격) (달러) GDP 성장률 (%)  \
# 23  2013                      1370.6                27178         3.2
# 24  2014                      1484.0                29242         3.2
# 25  2015                      1465.3                28724         2.8
# 26  2016                      1500.0                29287         2.9
# 27  2017                      1623.3                31605         3.2
# 28  2018                      1720.9                33346         2.7
#
#    수출 (100만달러) 수입 (100만달러) 총인구 (천명) 실업률 (%) 소비자물가지수 (2010=100)  \
# 23      559632      515586    50429     3.1               98.0
# 24      572665      525515    50747     3.5               99.3
# 25      526757      436499    51015     3.6              100.0
# 26      495426      406193    51218     3.7              101.0
# 27      573694      478478    51362     3.7              102.9
# 28      604860      535202    51607     3.8              104.5
#
#    조강생산량 (1000M/T) 인터넷 이용률 (%)
# 23           66061        84.8
# 24           71543        87.6
# 25           69670        89.9
# 26           68576        92.8
# 27           71030        95.1
# 28           69376        95.9

# %%
korea_growth_rate.dtypes
# Out:
# 연도                              int64
# 국내총생산(GDP)(당해년 가격) (10억US$)    object
# 1인당 GDP(당해년 가격) (달러)           object
# GDP 성장률 (%)                    object
# 수출 (100만달러)                    object
# 수입 (100만달러)                    object
# 총인구 (천명)                       object
# 실업률 (%)                        object
# 소비자물가지수 (2010=100)             object
# 조강생산량 (1000M/T)                object
# 인터넷 이용률 (%)                    object
# dtype: object

# %%
korea_growth_rate = korea_growth_rate.astype("float")

# %%
print(f"Korea Economic Growth Rate statistics summary")
korea_growth_rate.describe()
# Out:
# Korea Economic Growth Rate statistics summary
#                 연도  국내총생산(GDP)(당해년 가격) (10억US$)  1인당 GDP(당해년 가격) (달러)  \
# count     6.000000                     6.000000              6.000000
# mean   2015.500000                  1527.350000          29897.000000
# std       1.870829                   124.672383           2208.297081
# min    2013.000000                  1370.600000          27178.000000
# 25%    2014.250000                  1469.975000          28853.500000
# 50%    2015.500000                  1492.000000          29264.500000
# 75%    2016.750000                  1592.475000          31025.500000
# max    2018.000000                  1720.900000          33346.000000
#
#        GDP 성장률 (%)    수출 (100만달러)    수입 (100만달러)      총인구 (천명)   실업률 (%)  \
# count     6.000000       6.000000       6.000000      6.000000  6.000000
# mean      3.000000  555505.666667  482912.166667  51063.000000  3.566667
# std       0.228035   38766.447393   52300.060938    427.429058  0.250333
# min       2.700000  495426.000000  406193.000000  50429.000000  3.100000
# 25%       2.825000  534975.750000  446993.750000  50814.000000  3.525000
# 50%       3.050000  566148.500000  497032.000000  51116.500000  3.650000
# 75%       3.200000  573436.750000  523032.750000  51326.000000  3.700000
# max       3.200000  604860.000000  535202.000000  51607.000000  3.800000
#
#        소비자물가지수 (2010=100)  조강생산량 (1000M/T)  인터넷 이용률 (%)
# count             6.00000         6.000000     6.000000
# mean            100.95000     69376.000000    91.016667
# std               2.39729      1956.898873     4.365051
# min              98.00000     66061.000000    84.800000
# 25%              99.47500     68776.000000    88.175000
# 50%             100.50000     69523.000000    91.350000
# 75%             102.42500     70690.000000    94.525000
# max             104.50000     71543.000000    95.900000

# %%
plt.figure(figsize=(25, 25))
plt.suptitle("한국 경제 데이터", fontsize=30, x=0.4)

columns = list(set(korea_growth_rate.columns) - set(["연도"]))

# plt.subplot(len(columns), 1, 1)
for c in columns:
    korea_growth_rate[c] = korea_growth_rate[c].astype("int")
    ax =sns.lineplot(x="연도", y=f"{c}", data=korea_growth_rate, legend="brief", label=c)

# %% [markdown]
# - 각 column당 값들의 차이가 크기 때문에 같이 그래프를 그리기 보단 따로 그려서 변화 추이를 확인하는게 더 좋은 시각화 일 듯.

# %%
plt.figure(figsize=(20, 40))
plt.suptitle("한국 경제 데이터", fontsize=30, x=0.5)
plt.subplots_adjust(hspace=0.4, wspace=0.2)

columns = list(set(korea_growth_rate.columns) - set(["연도"]))

for i, c in enumerate(columns):
    plt.subplot(len(columns), 2, i+1)
    korea_growth_rate[c] = korea_growth_rate[c].astype("int")
    sns.lineplot(x="연도", y=f"{c}", data=korea_growth_rate, legend="brief", label=c)

# %%
data = korea_growth_rate.drop("연도", axis=1)
plt.figure(figsize=(30,20))
plt.suptitle("Korea Economic growth rate", fontsize=30)
ax = sns.violinplot(data=data, scale="width", palette="Set2")

# %% [markdown]
# 데이터가 적어서 굳이 의미 없을 듯 바로 상관성 분석

# %% [markdown]
# ### 상관성 분석
# ---

# %% [markdown]
# 상관성 분석을 위한 데이터 결합

# %%
# create annual feature in target data
target_data["연도"] = target_data["경매시간"].apply(lambda x : int(x[:4]))
target_data.head()
# Out:
#            경매시간 경매기준시분초  한우 평균경매 금액    연도
# 34896  20130102  221544       13203  2013
# 34867  20130103  221545       13743  2013
# 34811  20130104  221545       13945  2013
# 34666  20130107  221547       13470  2013
# 34634  20130108  221548       14040  2013

# %%
import os
os.chdir(r"C:\Users\a0105\Desktop\DSC\ddd\preprocessing")

target_data = pd.read_pickle('축산물_시계열 데이터로 변환(전국).pkl')

# %%
# Out:
#           주간날짜  한우 평균경매 금액_주간평균  돼지 탕박 경매 금액_주간평균  year  month
# 0   2013-01-06     13875.600000       3044.800000  2013      1
# 1   2013-01-13     13213.333333       2984.000000  2013      1
# 2   2013-01-20     12588.833333       2904.000000  2013      1
# 3   2013-01-27     12323.833333       2959.666667  2013      1
# 4   2013-02-03     12325.166667       2862.833333  2013      2
# ..         ...              ...               ...   ...    ...
# 293 2018-08-19     16835.000000       5305.000000  2018      8
# 294 2018-08-26     17555.000000       5207.500000  2018      8
# 295 2018-09-02     18369.000000       5548.000000  2018      9
# 296 2018-09-09     18757.000000       5754.000000  2018      9
# 297 2018-09-16     18757.000000       5754.000000  2018      9
#
# [298 rows x 5 columns]

# %%
merge_df = pd.merge(korea_growth_rate, target_data, left_on="연도",right_on='year', how="right")
print(f"Data Shape : {merge_df.shape}")
merge_df.head()
# Out:
# Data Shape : (298, 16)
#        연도  국내총생산(GDP)(당해년 가격) (10억US$)  1인당 GDP(당해년 가격) (달러)  GDP 성장률 (%)  \
# 0  2013.0                         1370                 27178            3
# 1  2013.0                         1370                 27178            3
# 2  2013.0                         1370                 27178            3
# 3  2013.0                         1370                 27178            3
# 4  2013.0                         1370                 27178            3
#
#    수출 (100만달러)  수입 (100만달러)  총인구 (천명)  실업률 (%)  소비자물가지수 (2010=100)  \
# 0       559632       515586     50429        3                  98
# 1       559632       515586     50429        3                  98
# 2       559632       515586     50429        3                  98
# 3       559632       515586     50429        3                  98
# 4       559632       515586     50429        3                  98
#
#    조강생산량 (1000M/T)  인터넷 이용률 (%)       주간날짜  한우 평균경매 금액_주간평균  돼지 탕박 경매 금액_주간평균  \
# 0            66061           84 2013-01-06     13875.600000       3044.800000
# 1            66061           84 2013-01-13     13213.333333       2984.000000
# 2            66061           84 2013-01-20     12588.833333       2904.000000
# 3            66061           84 2013-01-27     12323.833333       2959.666667
# 4            66061           84 2013-02-03     12325.166667       2862.833333
#
#    year  month
# 0  2013      1
# 1  2013      1
# 2  2013      1
# 3  2013      1
# 4  2013      2

# %%
merge_df.isnull().sum()
# Out:
# 연도                             0
# 국내총생산(GDP)(당해년 가격) (10억US$)    0
# 1인당 GDP(당해년 가격) (달러)           0
# GDP 성장률 (%)                    0
# 수출 (100만달러)                    0
# 수입 (100만달러)                    0
# 총인구 (천명)                       0
# 실업률 (%)                        0
# 소비자물가지수 (2010=100)             0
# 조강생산량 (1000M/T)                0
# 인터넷 이용률 (%)                    0
# 주간날짜                           0
# 한우 평균경매 금액_주간평균                0
# 돼지 탕박 경매 금액_주간평균               0
# year                           0
# month                          0
# dtype: int64

# %%
corr_data = merge_df.drop(["연도",'year','month'], axis=1)
corr = corr_data.corr()

corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col3 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col4 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col5 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col7 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col8 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col9 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col10 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row0_col11 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col3 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col4 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col5 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col7 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col8 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col9 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col10 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row1_col11 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col3 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col4 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col8 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col0 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col1 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col2 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col4 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col5 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col7 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col8 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col9 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col10 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row3_col11 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col2 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col3 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col5 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col10 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4df5c4b8_8506_11ea_8555_5076afa8d553row4_col11 {
#             background-color:  #485fd1;
#             color:  #f

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, fmt=".2f", annot=True)

# %%
ix = corr_data.corr().sort_values('한우 평균경매 금액_주간평균', ascending=False).index
data = corr_data.corr().sort_values("한우 평균경매 금액_주간평균", ascending=False)["한우 평균경매 금액_주간평균"]
positive_features = {x: data[x] for x in ix if data[x] >= 0}
negative_features = {x: data[x] for x in ix if data[x] <= 0}

print("===Positive Correlation Features====\n")
print(positive_features)
print()
print("===Negative Correlation Features====\n")
print(negative_features)
# Out:
# ===Positive Correlation Features====
#
# {'한우 평균경매 금액_주간평균': 1.0, '총인구 (천명)': 0.7877488230122816, '인터넷 이용률 (%)': 0.7659203724393034, '소비자물가지수 (2010=100)': 0.708952207106239, '국내총생산(GDP)(당해년 가격) (10억US$)': 0.5820234734345692, '1인당 GDP(당해년 가격) (달러)': 0.5544024767200516, '돼지 탕박 경매 금액_주간평균': 0.4601250888107784, '조강생산량 (1000M/T)': 0.29754926000917975}
#
# ===Negative Correlation Features====
#
# {'수출 (100만달러)': -0.2783465235336102, '수입 (100만달러)': -0.5341269320111455, 'GDP 성장률 (%)': -0.5942451682608553}

# %% [markdown]
# ### 결과해석
# ---
#
# - 전체적으로 양, 음의 상관계수 모두 큰 값이 나옴
# - 실업률과 GDP 성장률에 대한 상관관계에 대한 결과가 잘 이해가 되지 않지만, 그 이외에 값들은 어느정도 타당성 있는 결과 값이라고 볼 수 있음
#     - 추가로 실업률은 변화 추이가 거의 없어서 위 상관관계가 의미 있다고 볼 수 없음
# - 하지만 상관관계가 뚜렷하게 나오는 것에 있어 한번 같이 고민 해봐야할 필요가 있을 듯
#     - 결과가 잘 나와도 항상 의심하는 나의 성향임

# %%
merge_df.to_pickle('경제성장률merge.pkl')
